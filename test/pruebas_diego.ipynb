# %%
import pandas as pd
import numpy as np

df = pd.read_csv('../data/QueryGrosera_v4.csv', encoding= "latin_1")
df
# Out:
#        Reserva                 Tipo_Habitacion Clasificacion_tipo_habitacion  \
# 0         6576  ESTD C/BALCON  SN12ASB                                   ASB
# 1        82869  MV  LUXURY 1K  SN12GSU                                   GSU
# 2        82868  MV  LUXURY 2Q  SN12GSU                                   GSU
# 3        62469  JR SUITE 1K    SN12MJS                                   MJS
# 4        63254  JR SUITE 1K    SN12MJS                                   MJS
# ...        ...                             ...                           ...
# 79981    63042  LUXURY 1K      SN12GSU                                   GSU
# 79982    40799  MASTER SUITE 1KSN12GMS                                   GMS
# 79983    60997  MASTER SUITE 1KSN12GMS                                   GMS
# 79984    52804  MASTER SUITE 1KSN12GMS                                   GMS
# 79985    43773  ESTD DB        SN12AST                                   AST
#
#                                                  Paquete  \
# 0      WALK IN                                       ...
# 1      WALK IN                                       ...
# 2      WALK IN                                       ...
# 3      NINGUNO                                       ...
# 4      NINGUNO                                       ...
# ...                                                  ...
# 79981  WALK IN                                       ...
# 79982  WALK IN                                       ...
# 79983  WALK IN                                       ...
# 79984  WALK IN                                       ...
# 79985  WALK IN                                       ...
#
#                                                    Canal  \
# 0      FAX                                           ...
# 1                                      MULTIVACACIONES 2
# 2                                      MULTIVACACIONES 2
# 3      LADA 800 NACIONAL68                           ...
# 4                                      MULTIVACACIONES 1
# ...                                                  ...
# 79981  LADA 800 NACIONAL68                           ...
# 79982  LADA 800 NACIONAL68                           ...
# 79983  LADA 800 NACIONAL68                           ...
# 79984  LADA 800 NACIONAL68                           ...
# 79985  LADA 800 NACIONAL68                           ...
#
#                                                  Agencia  \
# 0      SUNWING VACATIONS                             ...
# 1      RESORT ADVANTAGE                              ...
# 2      RESORT ADVANTAGE                              ...
# 3      RESORT ADVANTAGE                              ...
# 4      RESORT ADVANTAGE                              ...
# ...                                                  ...
# 79981  PRICETRAVEL HOLDING                           ...
# 79982  CLIENTES PARTICULARES                         ...
# 79983  CLIENTES PARTICULARES                         ...
# 79984  CLIENTES PARTICULARES                         ...
# 79985  CIRCULO AZUL ELITE                            ...
#
#                      Estatus_res  Capacidad_hotel  Numero_personas  \
# 0                         SALIDA              735                1
# 1                         SALIDA              735                2
# 2                         SALIDA              735                3
# 3                         SALIDA              735                2
# 4                         SALIDA              735                2
# ...                          ...              ...              ...
# 79981  RESERVACION EN TRANSICION              735                2
# 79982  RESERVACION O (R)REGISTRO              735                2
# 79983                     SALIDA              735                2
# 79984                     SALIDA              735                2
# 79985  RESERVACION O (R)REGISTRO              735                2
#
#        Numero_adultos  Numero_men  Numero_noches  Numero_habitaciones  \
# 0                   1           0              1                    1
# 1                   2           0              4                    1
# 2                   2           0              4                    1
# 3                   2           0              2                    1
# 4                   2           0              2                    1
# ...               ...         ...            ...                  ...
# 79981               2           0              1                    1
# 79982               2           0             28                    1
# 79983               2           0             52                    1
# 79984               2           0             63                    1
# 79985               2           0              5                    1
#
#        IngresoMto FechaRegistro FechaLlegada  FechaSalida
# 0          101.60   2019-12-10   2020-01-15   2020-01-16
# 1          109.44   2019-03-19   2019-06-16   2019-06-20
# 2          109.44   2019-03-19   2019-06-16   2019-06-20
# 3          113.12   2019-02-22   2019-02-22   2019-02-24
# 4          113.70   2019-02-12   2019-02-13   2019-02-15
# ...           ...           ...          ...          ...
# 79981   132946.80   2019-03-14   2019-03-14   2019-03-14
# 79982   145544.00   2020-03-21   2021-01-13   2021-02-10
# 79983   166296.00   2019-02-12   2019-02-13   2019-04-06
# 79984   201474.00   2019-07-17   2020-01-11   2020-03-14
# 79985   655848.00   2020-01-13   2020-12-21   2020-12-26
#
# [79986 rows x 17 columns]

# %%
def remove_outliers(df, column_name, threshold=3):
    """
    Remove rows with outliers in a specific column of a DataFrame.
    
    Parameters:
        - df: pandas DataFrame
            The DataFrame containing the data.
        - column_name: str
            The name of the column to check for outliers.
        - threshold: int or float, optional (default=3)
            The number of standard deviations away from the mean to consider as an outlier.
    
    Returns:
        - pandas DataFrame
            The DataFrame with the outliers removed.
    """
    mean = np.mean(df[column_name])
    std = np.std(df[column_name])
    lower_bound = mean - threshold * std
    upper_bound = mean + threshold * std
    
    return df[(df[column_name] >= lower_bound) & (df[column_name] <= upper_bound)]

def is_high_season(date):
    year = date.year
        #verano, asueto revolución, invierno, asueto constitución, asueto petróleo
    if (pd.Timestamp(year=year, month=7, day=17) <= date <= pd.Timestamp(year=year, month=8, day=27)) or \
       (pd.Timestamp(year=year, month=11, day=18) <= date <= pd.Timestamp(year=year, month=11, day=20)) or \
       (pd.Timestamp(year=year, month=12, day=A18) <= date <= pd.Timestamp(year=year+1, month=1, day=5)) or \
       (pd.Timestamp(year=year, month=2, day=3) <= date <= pd.Timestamp(year=year, month=2, day=5)) or \
       (pd.Timestamp(year=year, month=3, day=16) <= date <= pd.Timestamp(year=year, month=3, day=18)) or \
        (pd.Timestamp(year=year, month=3, day=25) <= date <= pd.Timestamp(year=year, month=4, day=7)):
        return 'temporada alta'
    return 'temporada baja'

df_no_out = remove_outliers(df, "IngresoMto", threshold=3)

df_no_out['FechaLlegada'] = pd.to_datetime(df_no_out['FechaLlegada'])

df_no_out['Tipo_temporada'] = df_no_out['FechaLlegada'].apply(is_high_season)

df_no_out['Diferencia_reservacion_llegada'] = pd.to_datetime(df_no_out['FechaLlegada']) - pd.to_datetime(df['FechaRegistro'])

df_no_out
# Out:
# C:\Users\elian.rodriguez\AppData\Local\Temp\ipykernel_36520\2719864988.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_no_out['FechaLlegada'] = pd.to_datetime(df_no_out['FechaLlegada'])
# C:\Users\elian.rodriguez\AppData\Local\Temp\ipykernel_36520\2719864988.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_no_out['Tipo_temporada'] = df_no_out['FechaLlegada'].apply(is_high_season)
# C:\Users\elian.rodriguez\AppData\Local\Temp\ipykernel_36520\2719864988.py:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_no_out['Diferencia_reservacion_llegada'] = pd.to_datetime(df_no_out['FechaLlegada']) - pd.to_datetime(df['FechaRegistro'])
#        Reserva                 Tipo_Habitacion Clasificacion_tipo_habitacion  \
# 0         6576  ESTD C/BALCON  SN12ASB                                   ASB
# 1        82869  MV  LUXURY 1K  SN12GSU                                   GSU
# 2        82868  MV  LUXURY 2Q  SN12GSU                                   GSU
# 3        62469  JR SUITE 1K    SN12MJS                                   MJS
# 4        63254  JR SUITE 1K    SN12MJS                                   MJS
# ...        ...                             ...                           ...
# 79212    84742  LUXURY 2Q      SN12GSU                                   GSU
# 79213    55939  LUXURY 2Q      SN12GSU                                   GSU
# 79214     1379  LUXURY 2Q      SN12GSU                                   GSU
# 79215     1378  LUXURY 1K      SN12GSU                                   GSU
# 79216    27417  LUXURY 2Q      SN12GSU                                   GSU
#
#                                                  Paquete  \
# 0      WALK IN                                       ...
# 1      WALK IN                                       ...
# 2      WALK IN                                       ...
# 3      NINGUNO                                       ...
# 4      NINGUNO                                       ...
# ...                                                  ...
# 79212  WALK IN                                       ...
# 79213  WALK IN                                       ...
# 79214  WALK IN                                       ...
# 79215  WALK IN                                       ...
# 79216  WALK IN                                       ...
#
#                                                    Canal  \
# 0      FAX                                           ...
# 1                                      MULTIVACACIONES 2
# 2                                      MULTIVACACIONES 2
# 3      LADA 800 NACIONAL68                           ...
# 4                                      MULTIVACACIONES 1
# ...                                                  ...
# 79212  INTERNET                                      ...
# 79213  INTERNET                                      ...
# 79214  LADA 800 NACIONAL68                           ...
# 79215  LADA 800 NACIONAL68                           ...
# 79216  LADA 800 NACIONAL68                           ...
#
#                                                  Agencia  \
# 0      SUNWING VACATIONS                             ...
# 1      RESORT ADVANTAGE                              ...
# 2      RESORT ADVANTAGE                              ...
# 3      RESORT ADVANTAGE                              ...
# 4      RESORT ADVANTAGE                              ...
# ...                                                  ...
# 79212                                       HOTELES S.A.
# 79213                                       HOTELES S.A.
# 79214  PRICETRAVEL HOLDING                           ...
# 79215  PRICETRAVEL HOLDING                           ...
# 79216  QUALITY SERVICES MORELIA                      ...
#
#                      Estatus_res  Capacidad_hotel  Numero_personas  \
# 0                         SALIDA              735                1
# 1                         SALIDA              735                2
# 2                         SALIDA              735                3
# 3                         SALIDA              735                2
# 4                         SALIDA              735                2
# ...                          ...              ...              ...
# 79212                     SALIDA              735                3
# 79213  RESERVACION O (R)REGISTRO              735                2
# 79214                     SALIDA              735                2
# 79215                     SALIDA              735                2
# 79216                     SALIDA              735                3
#
#        Numero_adultos  Numero_men  Numero_noches  Numero_habitaciones  \
# 0                   1           0              1                    1
# 1                   2           0              4                    1
# 2                   2           0              4                    1
# 3                   2           0              2                    1
# 4                   2           0              2                    1
# ...               ...         ...            ...                  ...
# 79212               3           0              5                    1
# 79213               2           0              4                    1
# 79214               2           0              6                    1
# 79215               2           0              6                    1
# 79216               3           0              7                    1
#
#        IngresoMto FechaRegistro FechaLlegada  FechaSalida  Tipo_temporada  \
# 0          101.60   2019-12-10    2020-01-15  2020-01-16   temporada baja
# 1          109.44   2019-03-19    2019-06-16  2019-06-20   temporada baja
# 2          109.44   2019-03-19    2019-06-16  2019-06-20   temporada baja
# 3          113.12   2019-02-22    2019-02-22  2019-02-24   temporada baja
# 4          113.70   2019-02-12    2019-02-13  2019-02-15   temporada baja
# ...           ...           ...          ...          ...             ...
# 79212    26520.15   2019-07-12    2019-07-17  2019-07-22   temporada alta
# 79213    26521.04   2020-03-12    2020-12-28  2021-01-01   temporada alta
# 79214    26527.44   2019-03-19    2019-12-26  2020-01-01   temporada alta
# 79215    26527.56   2019-03-19    2019-12-26  2020-01-01   temporada alta
# 79216    26572.00   2019-09-21    2019-10-02  2019-10-09   temporada baja
#
#       Diferencia_reservacion_llegada
# 0                            36 days
# 1                            89 days
# 2                            89 days
# 3                             0 days
# 4                             1 days
# ...                              ...
# 79212                         5 days
# 79213                       291 days
# 79214                       282 days
# 79215                       282 days
# 79216                        11 days
#
# [79217 rows x 19 columns]

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.cluster import KMeans
from sklearn.pipeline import Pipeline
import pandas as pd
from kneed import KneeLocator

# Asumiendo que df_no_out ya está definido y limpio
columns_to_use = ['Tipo_Habitacion', 'Clasificacion_tipo_habitacion', 'Paquete', 'Canal', 'Estatus_res', 'Capacidad_hotel', 'Numero_personas', 'Numero_adultos', 'Numero_noches', 'IngresoMto', 'Tipo_temporada']
df_selected = df_no_out[columns_to_use]

# Preprocesamiento con OneHotEncoder para variables categóricas y StandardScaler para ingresos
categorical_features = ['Tipo_Habitacion', 'Clasificacion_tipo_habitacion', 'Paquete', 'Canal', 'Estatus_res', "Tipo_temporada"]
numeric_features = ['Capacidad_hotel', 'Numero_personas', 'Numero_adultos', 'Numero_noches', 'IngresoMto']

categorical_transformer = OneHotEncoder(handle_unknown='ignore')
numeric_transformer = Pipeline(steps=[
    ('scaler', StandardScaler())
])

preprocessor = ColumnTransformer(
    transformers=[
        ('num', numeric_transformer, numeric_features),
        ('cat', categorical_transformer, categorical_features)
    ])

# Preprocesar los datos
data_transformed = preprocessor.fit_transform(df_selected)

# Realizar el análisis de codo
sum_of_squared_distances = []
K = range(1, 10)  # Puedes ajustar este rango según tus necesidades y recursos
for k in K:
    km = KMeans(n_clusters=k, random_state=42)
    km = km.fit(data_transformed)
    sum_of_squared_distances.append(km.inertia_)

# Encontrar el codo usando el método de la máxima curvatura (KneeLocator)
kn = KneeLocator(K, sum_of_squared_distances, curve='convex', direction='decreasing')
n_clusters_optimo = 6# kn.knee if kn.knee else 3  # Utiliza 3 como valor predeterminado si el método no encuentra un codo

# Visualizar el análisis de codo y el codo detectado
plt.figure(figsize=(10, 6))
plt.plot(K, sum_of_squared_distances, 'bx-')
plt.xlabel('Número de clusters')
plt.ylabel('Suma de distancias cuadradas')
plt.title('Análisis de Codo para Determinar el Número Óptimo de Clusters')
if kn.knee:
    plt.vlines(kn.knee, plt.ylim()[0], plt.ylim()[1], linestyles='dashed')
    print(f"El número óptimo de clusters detectado es: {kn.knee}")
else:
    print("No se detectó un punto de codo claro.")
plt.show()

# Crear y ajustar el modelo de K-Means con el número óptimo de clusters
kmeans_final = KMeans(n_clusters=n_clusters_optimo, random_state=42)
pipeline_final = Pipeline(steps=[('preprocessor', preprocessor),
                                 ('clusterer', kmeans_final)])

pipeline_final.fit(df_selected)

# Predecir las etiquetas del cluster
labels_final = pipeline_final.predict(df_selected)

# Visualizar los tamaños de los clusters finales
plt.hist(labels_final, bins=range(n_clusters_optimo + 1), align='left', rwidth=0.8)
plt.xlabel('Cluster')
plt.ylabel('Count')
plt.title('Tamaño de los Clusters Finales')
plt.show()
# Out:
# El número óptimo de clusters detectado es: 4

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Añadimos las etiquetas de los clusters al dataframe
df_selected['Cluster'] = labels_final

# Variables numéricas para análisis
numeric_features = ['Capacidad_hotel', 'Numero_personas', 'Numero_adultos', 'Numero_noches', 'IngresoMto']

# Gráficos para variables numéricas
fig, axes = plt.subplots(len(numeric_features), 1, figsize=(10, 5 * len(numeric_features)))
for i, col in enumerate(numeric_features):
    sns.barplot(x='Cluster', y=col, data=df_selected, ax=axes[i], ci=None)
    axes[i].set_title(f'Media de {col} por Cluster')
plt.tight_layout()
plt.show()

# Variables categóricas para análisis
categorical_features = ['Tipo_Habitacion', 'Clasificacion_tipo_habitacion', 'Paquete', 'Canal', 'Estatus_res']

# Gráficos para variables categóricas
for feature in categorical_features:
    plt.figure(figsize=(12, 6))
    sns.countplot(x='Cluster', hue=feature, data=df_selected)
    plt.title(f'Distribución de {feature} por Cluster')
    plt.legend(title=feature, bbox_to_anchor=(1.05, 1), loc='upper left')
    plt.tight_layout()
    plt.show()
# Out:
# C:\Users\elian.rodriguez\AppData\Local\Temp\ipykernel_36520\2127989833.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_selected['Cluster'] = labels_final
# C:\Users\elian.rodriguez\AppData\Local\Temp\ipykernel_36520\2127989833.py:13: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x='Cluster', y=col, data=df_selected, ax=axes[i], ci=None)
# C:\Users\elian.rodriguez\AppData\Local\Temp\ipykernel_36520\2127989833.py:13: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x='Cluster', y=col, data=df_selected, ax=axes[i], ci=None)
# C:\Users\elian.rodriguez\AppData\Local\Temp\ipykernel_36520\2127989833.py:13: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x='Cluster', y=col, data=df_selected, ax=axes[i], ci=None)
# C:\Users\elian.rodriguez\AppData\Local\Temp\ipykernel_36520\2127989833.py:13: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x='Cluster', y=col, data=df_selected, ax=axes[i], ci=None)
# C:\Users\elian.rodriguez\AppData\Local\Temp\ipykernel_36520\2127989833.py:13: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x='Cluster', y=col, data=df_selected, ax=axes[i], ci=None)

# %%
from sklearn.metrics import silhouette_score

# Asumimos que 'data_transformed' son tus datos preprocesados y 'labels_final' las etiquetas de clusters del modelo final
silhouette_avg = silhouette_score(data_transformed, labels_final)
print(f"El índice Silhouette promedio es: {silhouette_avg}")
# Out:
# El índice Silhouette promedio es: 0.16814800619566386

# %%
from sklearn.metrics import davies_bouldin_score

# Asumimos que 'data_transformed' son tus datos preprocesados y 'labels_final' las etiquetas de clusters del modelo final
db_index = davies_bouldin_score(data_transformed, labels_final)
print(f"El índice Davies-Bouldin es: {db_index}")
# Out:
# ---------------------------------------------------------------------------
# InvalidParameterError                     Traceback (most recent call last)
# Cell In[36], line 4
#       1 from sklearn.metrics import davies_bouldin_score
#       3 # Asumimos que 'data_transformed' son tus datos preprocesados y 'labels_final' las etiquetas de clusters del modelo final
# ----> 4 db_index = davies_bouldin_score(data_transformed, labels_final)
#       5 print(f"El índice Davies-Bouldin es: {db_index}")
#
# File c:\Users\elian.rodriguez\multicripto_omega\venv\Lib\site-packages\sklearn\utils\_param_validation.py:203, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     200 to_ignore += ["self", "cls"]
#     201 params = {k: v for k, v in params.arguments.items() if k not in to_ignore}
# --> 203 validate_parameter_constraints(
#     204     parameter_constraints, params, caller_name=func.__qualname__
#     205 )
#     207 try:
#     208     with config_context(
#     209         skip_parameter_validation=(
#     210             prefer_skip_nested_validation or global_skip_validation
#     211         )
#     212     ):
#
# File c:\Users\elian.rodriguez\multicripto_omega\venv\Lib\site-packages\sklearn\utils\_param_validation.py:95, in validate_parameter_constraints(parameter_constraints, params, caller_name)
#      89 else:
#      90     constraints_str = (
#      91         f"{', '.join([str(c) for c in constraints[:-1]])} or"
#      92         f" {constraints[-1]}"
#      93     )
# ---> 95 raise InvalidParameterError(
#      96     f"The {param_name!r} parameter of {caller_name} must be"
#      97     f" {constraints_str}. Got {param_val!r} instead."
#      98 )
#
# InvalidParameterError: The 'X' parameter of davies_bouldin_score must be an array-like. Got <79217x69 sparse matrix of type '<class 'numpy.float64'>'
# 	with 792170 stored elements in Compressed Sparse Row format> instead.
